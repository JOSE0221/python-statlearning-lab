# %% [markdown]
# ## Credit Risk prediction using Neural Nets
#
# This assignment is due on:
#
# -
#
# Send me your Jupyter Notebook to my email (eddiezago500@gmail.com) in the following format: hw3_name_surname.ipynb. Make sure to copy the whole 'assignment3' folder to your DropBox or local computer and use relative paths, as we have seen in class. I should be able to run all your codes without changing the paths.
#
# e.g: '../data/input/file.xlsx'
#
# Overall Instructions:
#
# One interesting practical and business use of ML and DL is credit default prediction. Most big financial companies have rich data sets containing information of their clients credit history, personal information and if they defaulted or not when they received a loan. These datasets are frequently utilized to train models that subsequently aid companies in determining whether to extend credit to new clients, what interest rates to offer, and the appropriate loan amounts.
#
# The data set was obtained from Kaggle: https://www.kaggle.com/datasets/laotse/credit-risk-dataset/data. Follow that link to obtain the description for those variables.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
import seaborn as sns

# %% [markdown]
# 1) Import the data set and take a look at all the variables using the function .info()

# %%
df = pd.read_csv('../data/credit_risk_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# 2) Pre-processing: One important aspect of ML is data pre-processing. For example, ff you look closely at the data, you will notice that you have 3 categorical variables, that are coded as strings, and cannot be inputed into a model like that. The way to go with these variables is to generate dummies for each category-variable.
#
# 2.1) Generate dummies for each categorical variable (person_home_ownership, loan_intent, loan_grade, cb_person_default_on_file). (Hint: you should end up with 29 columns and there is pandas function that does this for you.)

# %%
loan = pd.get_dummies(df['loan_intent'], prefix='loan_int')
df = pd.concat([df, loan], axis=1)

loanx = pd.get_dummies(df['loan_grade'], prefix='loan_grade')
df = pd.concat([df, loanx], axis=1)

loany = pd.get_dummies(df['person_home_ownership'], prefix='pho')
df = pd.concat([df, loany], axis=1)

loanz = pd.get_dummies(df['cb_person_default_on_file'], prefix='cbp_default')
df = pd.concat([df, loanz], axis=1)

# %% [markdown]
# 2.2) Remove any NA values:

# %%
df = df.dropna()

# %% [markdown]
# 2.3) Plot the distribution of labels using matplotlib.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="loan_status", data=df, palette="Set2")
plt.xlabel("Loan Status")
plt.ylabel("Count")
plt.title("Countplot of Loan Status")
plt.show()

# %% [markdown]
# As per usual with credit risk datasets, there is a clear over sampling in the no default class. There are usually many more people that do pay up their loans than people that default (if not all banks would go bankrupt).
#
# We can solve it using the following function, which I will provide to you (you just have to run it)
#
# 2.4) Define X (set of predictors) and y (label) then run the code provided:

# %%
loan_l = loan.columns.tolist()
loanx_l = loanx.columns.tolist()
loany_l = loany.columns.tolist()
loanz_l = loanz.columns.tolist()

X = df[loan_l + loanx_l + loany_l + loanz_l + ['person_age', 'person_income', 
                                             'loan_amnt', 'loan_int_rate']]

y = df['loan_status']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# 2.5) It is also, great practice, to remove any outliers that might affect the prediction of our model. For this, we can drop them or standarize them so that they are comparable between each other (with respect to the standard deviation) and have less variance. The function is also provided to you:

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_resampled)
x_scaled = scaler.transform(x_resampled)

# %% [markdown]
# 3) Now we have the data base ready to train our model and do the prediction. Let us start with a benchmark model, such as the random forest.
#
# 3.1) Split the dataset into training and validation:

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_resampled, test_size=0.15, 
                                                    random_state = 23)

# %% [markdown]
# 3.2) Train a random forest (without using the hyper-parameter optimal grid, since it takes too much time, so use the initial one in the notes) and print and record the training and validation accuracy. Comment on the results (do you have over-fitting? what can you do to improve the accuracy?):

# %%
clf=RandomForestClassifier(n_estimators=100)

clf.fit(x_train, y_train)

y_pred=clf.predict(x_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Accuracy:", metrics.accuracy_score(y_train,  clf.predict(x_train))*100)
# Out:
# Accuracy: 0.9433962264150944
# Accuracy: 100.0

# %% [markdown]
# 4) It is common practice, while training a model for prediction, to try different models, different sets of hyper-parameters, and to choose the best one. Given this, in this last section we are going to try surpass the prediction of the random forest using Neural Nets.
#
# 4.1) Define (with code) and train a (Neural Net with more than one node and more than 1 hidden layer). Report the validation accuracy.
#
# pd. You have freedom to choose all the other relevant hyper-parameters, I just set up for you the AdamW optimizer (which is the most commonly used) and the loss and metrics. Recall the initial shape is equal to the number of X variables.
#
# Extra point if you surpass the 90% accuracy threshold. Leave the print in the code, so I do not have to spend time re-training each model.

# %%
i = Input(shape=(x_train.shape[1],), name='input')
h = Dense(units=64, activation='relu', name='hidden1')(i)
h = Dropout(0.3)(h)
h = Dense(units=64, activation='relu', name='hidden2')(h)
h = Dropout(0.3)(h)
o = Dense(units=1, activation='sigmoid', name='output')(h)

MLP = Model(inputs=i, outputs=o)
MLP.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 23)]              0
#
#  hidden1 (Dense)             (None, 64)                1536
#
#  dropout (Dropout)           (None, 64)                0
#
#  hidden2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  output (Dense)              (None, 1)                 65
#
# =================================================================
# Total params: 5,761
# Trainable params: 5,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=.001)

MLP.compile(optimizer=optimizer, loss='binary_crossentropy', metrics = ['accuracy'])

# %%
model = MLP.fit(x=x_train, y=y_train, batch_size=4, epochs=20, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/20
# 8582/8582 - 21s - loss: 0.1805 - accuracy: 0.9344 - val_loss: 0.1645 - val_accuracy: 0.9381 - 21s/epoch - 2ms/step
# Epoch 2/20
# 8582/8582 - 20s - loss: 0.1795 - accuracy: 0.9352 - val_loss: 0.1619 - val_accuracy: 0.9394 - 20s/epoch - 2ms/step
# Epoch 3/20
# 8582/8582 - 19s - loss: 0.1800 - accuracy: 0.9359 - val_loss: 0.1636 - val_accuracy: 0.9384 - 19s/epoch - 2ms/step
# Epoch 4/20
# 8582/8582 - 17s - loss: 0.1765 - accuracy: 0.9351 - val_loss: 0.1592 - val_accuracy: 0.9410 - 17s/epoch - 2ms/step
# Epoch 5/20
# 8582/8582 - 20s - loss: 0.1757 - accuracy: 0.9358 - val_loss: 0.1633 - val_accuracy: 0.9400 - 20s/epoch - 2ms/step
# Epoch 6/20
# 8582/8582 - 20s - loss: 0.1817 - accuracy: 0.9362 - val_loss: 0.1613 - val_accuracy: 0.9384 - 20s/epoch - 2ms/step
# Epoch 7/20
# 8582/8582 - 20s - loss: 0.1745 - accuracy: 0.9361 - val_loss: 0.1592 - val_accuracy: 0.9415 - 20s/epoch - 2ms/step
# Epoch 8/20
# 8582/8582 - 20s - loss: 0.1771 - accuracy: 0.9363 - val_loss: 0.1589 - val_accuracy: 0.9394 - 20s/epoch - 2ms/step
# Epoch 9/20
# 8582/8582 - 20s - loss: 0.1773 - accuracy: 0.9356 - val_loss: 0.1582 - val_accuracy: 0.9426 - 20s/epoch - 2ms/step
# Epoch 10/20
# 8582/8582 - 20s - loss: 0.1751 - accuracy: 0.9369 - val_loss: 0.1615 - val_accuracy: 0.9360 - 20s/epoch - 2ms/step
# Epoch 11/20
# 8582/8582 - 20s - loss: 0.1749 - accuracy: 0.9360 - val_loss: 0.1615 - val_accuracy: 0.9381 - 20s/epoch - 2ms/step
# Epoch 12/20
# 8582/8582 - 21s - loss: 0.1764 - accuracy: 0.9358 - val_loss: 0.1611 - val_accuracy: 0.9371 - 21s/epoch - 2ms/step
# Epoch 13/20
# 8582/8582 - 20s - loss: 0.1764 - accuracy: 0.9362 - val_loss: 0.1585 - val_accuracy: 0.9394 - 20s/epoch - 2ms/step
# Epoch 14/20
# 8582/8582 - 20s - loss: 0.1730 - accuracy: 0.9363 - val_loss: 0.1573 - val_accuracy: 0.9386 - 20s/epoch - 2ms/step
# Epoch 15/20
# 8582/8582 - 20s - loss: 0.1820 - accuracy: 0.9368 - val_loss: 0.1599 - val_accuracy: 0.9394 - 20s/epoch - 2ms/step
# Epoch 16/20
# 8582/8582 - 20s - loss: 0.1779 - accuracy: 0.9361 - val_loss: 0.1590 - val_accuracy: 0.9373 - 20s/epoch - 2ms/step
# Epoch 17/20
# 8582/8582 - 20s - loss: 0.1758 - accuracy: 0.9358 - val_loss: 0.1597 - val_accuracy: 0.9381 - 20s/epoch - 2ms/step
# Epoch 18/20
# 8582/8582 - 20s - loss: 0.1785 - accuracy: 0.9363 - val_loss: 0.1584 - val_accuracy: 0.9402 - 20s/epoch - 2ms/step
# Epoch 19/20
# 8582/8582 - 20s - loss: 0.1775 - accuracy: 0.9362 - val_loss: 0.1579 - val_accuracy: 0.9381 - 20s/epoch - 2ms/step
# Epoch 20/20
# 8582/8582 - 20s - loss: 0.1765 - accuracy: 0.9375 - val_loss: 0.1605 - val_accuracy: 0.9389 - 20s/epoch - 2ms/step

# %%
loss, acc = MLP.evaluate(x=x_test, y=y_test)
print(loss, acc)
# Out:
# 211/211 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.9342
# 0.16829386353492737 0.9341850876808167

# %% [markdown]
# 4.2) Finally, plot the Learning Curve (only training and validation accuracy):

# %%
plt.figure(figsize=(12, 5))
plt.plot(model.history['accuracy'], label='Training', linewidth=2)
plt.plot(model.history['val_accuracy'], label='Validation', linewidth=2)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
MLP.history['accuracy']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 MLP.history['accuracy']
#
# TypeError: 'History' object is not subscriptable
